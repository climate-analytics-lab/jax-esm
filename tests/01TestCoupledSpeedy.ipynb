# %% [markdown]
# # Coupled Model Test
#
# Speedy + Slab Ocean Model

# %%
import os
#os.environ["JAX_PLATFORM_NAME"] = "cpu"

import jax
print("JAX device:", jax.devices())
jax.config.update('jax_disable_jit', False) # Turn off JIT because of an issue in shortwave_radiation.py:169
jax.config.update("jax_debug_infs", True) # doesn't add any time since the saved time is otherwise spent getting the nodal quantities
jax.config.update("jax_debug_nans", False) # some physics fields might be nan
# Out:
# JAX device: [CpuDevice(id=0)]

# %%
import sys
from pathlib import Path

paths_check = [
    (Path(os.path.abspath(".")) / ".." / ".." / "jax-gcm").resolve(),
    (Path(os.path.abspath(".")) / "..").resolve(),
]

for module_path in paths_check:
    module_path = str(module_path)
    if module_path in sys.path:
        print("Path exist: ", module_path)
    else:
        print("Add Path: ", module_path)
        sys.path.append(module_path)
# Out:
# Add Path:  /home/t2hsu/projects/jax-gcm
# Add Path:  /home/t2hsu/projects/jax-esm

# %%
import numpy as np
import xarray as xr
import pandas as pd

from collections import namedtuple

import jcm

import jax_esm
from jax_esm.Coupler import Coupler
from jax_esm.components.base import ComponentConfig
from jax_esm.components.Speedy import Speedy
from jax_esm.components.SlabOceanModel import SlabOceanModel
from jax_esm.components.FluxModel import FluxModel
# Out:
# Path exist:  /home/t2hsu/projects/jax-gcm
# Path exist:  /home/t2hsu/projects/jax-esm

# %% [markdown]
# ## Create Boundary File

# %%
from pathlib import Path
from jcm.model import get_coords
from jcm.boundaries import initialize_boundaries

# Prepare boundary file
boundary_file = (Path(jax_esm.__file__).parent / "data" / "boundaries_daily.nc").resolve()

if not boundary_file.exists():
    print("Boundary file %s does not exist. Need to produce it." % (str(boundary_file),))
    import subprocess, sys
    interpolation_file = boundary_file.parent / "interpolate.py"
    subprocess.run([sys.executable, str(interpolation_file)], check=True)

if boundary_file.exists():
    print("Boundary file %s exists!" % (str(boundary_file), ) )
else:
    raise Exception("Something went wrong. The daily file is not generated. Please check.")

boundaries = initialize_boundaries(
    boundary_file,
    get_coords().horizontal
)
# Out:
# Boundary file /home/t2hsu/projects/jax-esm/jax_esm/data/boundaries_daily.nc exists!

# %% [markdown]
# ## Create Model
#
# Currently, the time steps are not checked to be consistent. Should be checked in the future.

# %%
start_dt = pd.Timestamp("2001-01-01")

total_simulation_time =  5 * 86400.0 # sec
coupler_time_step      =  86400.0  # sec
coupler_steps = int(total_simulation_time / coupler_time_step)

atm_substeps          =  12           # count
atm_save_interval     =  coupler_time_step / atm_substeps # coupler_time_step # sec

ocn_substeps          =  1            # count
ocn_save_interval     = 24 *  3600.0  # sec

flx_substeps          =  1            # count
flx_save_interval     = 24 *  3600.0  # sec

# %%
# Coupler Config
config_master = dict(
    total_simulation_time = total_simulation_time,
    time_step = coupler_time_step,
)

# Atmosphere model
config_atm = ComponentConfig(
    name = "atm",
    start_dt = start_dt,
    timestep = coupler_time_step,
    substeps = atm_substeps,
    save_interval = atm_save_interval,
    grid = None,
    params = dict(
        boundaries = boundaries,
    ),
)

model_atm = Speedy(
    config = config_atm,
)

# Ocean model
config_ocn = ComponentConfig(
    name = "ocn",
    start_dt = start_dt,
    timestep = coupler_time_step,
    substeps = ocn_substeps,
    save_interval = ocn_save_interval,
    grid = None,
    params = dict(
        coords = model_atm.model.coords,
        geometry = model_atm.model.geometry,
        relaxation_time = 86400.0 * 60,
        boundaries = boundaries,
        boundary_file = boundary_file,
    ),
)
model_ocn = SlabOceanModel(config_ocn)

# Flux model
config_flx = ComponentConfig(
    name = "flx",
    start_dt = start_dt,
    timestep = coupler_time_step,
    substeps = flx_substeps,
    save_interval = flx_save_interval,
    grid = None,
    params = dict(
        coords = model_atm.model.coords,
        geometry = model_atm.model.geometry,
        boundaries = boundaries,
        boundary_file = boundary_file,
    ),
)
model_flx = FluxModel(config_flx)
# Out:
# Boundary exists.
# Boundary file:  /home/t2hsu/projects/jax-esm/jax_esm/data/boundaries_daily.nc
# fmask_ocn and init_T do share the same mask.

# %%
coupler = Coupler(
    config = config_master,
    components = dict(
        flx = model_flx,
        atm = model_atm,
        ocn = model_ocn,
    ), 
)

# %% [markdown]
# # Plot initial conditions

# %%
import xarray as xr

init_SST = xr.DataArray(
    data = model_ocn.init_state.T,
    dims = ["lon", "lat"],
)

(init_SST-273.15).plot.contourf(x='lon', y='lat', cmap="gnuplot2", add_colorbar=True, levels=np.arange(-2, 36, 2), extends="both")
# Out:
# /home/t2hsu/miniconda3/envs/jax/lib/python3.13/site-packages/xarray/plot/dataarray_plot.py:2139: UserWarning: The following kwargs were not used by contour: 'extends'
#   primitive = ax.contourf(x, y, z, **kwargs)

# %% [markdown]
# # Run the Model
#
# You can set `jax_scan = True` to test if `jax.lax.scan` will work.
# Currently, it does not because the first input carry and output of the first time step do not have the same shape. `PhysicsData` in `Prediction` is a stacked variable, and its stacked shape is not pre-determined.
#
# When set `jax_scan = False`, use the ad-hoc scan defined in `Coupler.py`.

# %%
import numpy as np

final_cpl_state, pred = coupler.run(
    total_steps = coupler_steps,
    timestep = jcm.date.Timedelta.from_timedelta64(np.timedelta64(int(coupler_time_step), 's')),
    jax_scan = False, 
)
# Out:
# The 0-th iteration.
# /home/t2hsu/miniconda3/envs/jax/lib/python3.13/site-packages/jax/_src/numpy/scalar_types.py:49: UserWarning: Explicitly requested dtype int64 requested in asarray is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return jax.numpy.asarray(x, dtype=self.dtype)
# The 1-th iteration.
# The 2-th iteration.
# The 3-th iteration.
# The 4-th iteration.
# Execution time: 59.6 seconds.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ocean Model Diagnostics

# %%
ocn_traj_ds = model_ocn.convertTrajectoryToXarray(pred["ocn"])

# %%
ocn_traj_ds["mld"].plot(x='lon', y='lat', col="time", col_wrap=3)

# %%
ax = (ocn_traj_ds["T"]-ocn_traj_ds["T"].isel(time=0)).plot.contourf(x='lon', y='lat', col="time", col_wrap=3, cmap="bwr", levels=np.linspace(-1, 1, 21)*2)
plt.suptitle("SST")
# Out:
# Text(0.5, 0.98, 'SST')

# %%
ax = (ocn_traj_ds["sim_time"]/86400).plot(x='time', marker="o", markersize=10)
plt.grid(True)

# %% [markdown]
# ## Flux Diagnostics

# %%
flx_traj_ds = model_flx.convertTrajectoryToXarray(pred["flx"])

# %%
flx_traj_ds["hfluxn"].isel(layer=0).plot(x='lon', y='lat', col="time", col_wrap=3)

# %% [markdown]
# ## Verify What Atmosphere Model Sees

# %%
import numpy as np
import jax
from jcm.model import Predictions
import xarray as xr

time_slice = slice(0, None, atm_substeps)

atm_model = coupler.components["atm"]
atm_pred = pred["atm"]

print(type(atm_pred))

# This function seems to have trouble dealing with stacked data.
pred_ds = atm_model.model.predictions_to_xarray(pred["atm"])
# Out:
# <class 'jcm.model.Predictions'>
# original keys:  ['shortwave_rad.qcloud.addressable_shards', 'shortwave_rad.fsol.addressable_shards', 'shortwave_rad.rsds.addressable_shards', 'shortwave_rad.rsns.addressable_shards', 'shortwave_rad.ozone.addressable_shards', 'shortwave_rad.ozupp.addressable_shards', 'shortwave_rad.zenit.addressable_shards', 'shortwave_rad.stratz.addressable_shards', 'shortwave_rad.gse.addressable_shards', 'shortwave_rad.icltop', 'shortwave_rad.cloudc.addressable_shards', 'shortwave_rad.cloudstr.addressable_shards', 'shortwave_rad.ftop.addressable_shards', 'shortwave_rad.dfabs.addressable_shards', 'shortwave_rad.compute_shortwave', 'longwave_rad.dfabs.addressable_shards', 'longwave_rad.ftop.addressable_shards', 'convection.se.addressable_shards', 'convection.iptop.addressable_shards', 'convection.cbmf.addressable_shards', 'convection.precnv.addressable_shards', 'mod_radcon.ablco2', 'mod_radcon.alb_l.addressable_shards', 'mod_radcon.alb_s.addressable_shards', 'mod_radcon.albsfc.addressable_shards', 'mod_radcon.snowc.addressable_shards', 'mod_radcon.tau2', 'mod_radcon.st4a', 'mod_radcon.stratc', 'mod_radcon.flux', 'humidity.rh.addressable_shards', 'humidity.qsat.addressable_shards', 'condensation.precls.addressable_shards', 'condensation.dtlsc.addressable_shards', 'condensation.dqlsc.addressable_shards', 'surface_flux.ustr', 'surface_flux.vstr.addressable_shards', 'surface_flux.shf.addressable_shards', 'surface_flux.evap.addressable_shards', 'surface_flux.rlus.addressable_shards', 'surface_flux.rlds.addressable_shards', 'surface_flux.rlns.addressable_shards', 'surface_flux.hfluxn.addressable_shards', 'surface_flux.tsfc', 'surface_flux.tskin.addressable_shards', 'surface_flux.u0.addressable_shards', 'surface_flux.v0.addressable_shards', 'surface_flux.t0.addressable_shards', 'date.tyear.addressable_shards', 'date.model_year', 'date.model_step', 'date.dt_seconds', 'land_model.stl_lm.addressable_shards', 'land_model.stl_am.addressable_shards']
# [Shard(device=CpuDevice(id=0), index=(slice(None, None, None), slice(None, None, None), slice(None, None, None)), replica_id=0, data=[[[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[3.04243341e-02 5.32134026e-02 1.34971244e-02 ... 6.31982181e-03
#    3.81882512e-03 0.00000000e+00]
#   [2.93409936e-02 5.15261814e-02 1.18978359e-02 ... 6.53264252e-03
#    3.94941866e-03 0.00000000e+00]
#   [2.81071831e-02 4.97750230e-02 1.12590371e-02 ... 6.04993245e-03
#    3.87896900e-03 0.00000000e+00]
#   ...
#   [3.26992422e-02 5.76404296e-02 2.37922855e-02 ... 3.13862954e-04
#    2.18786043e-03 1.91094674e-04]
#   [3.21092457e-02 5.63131012e-02 1.95854567e-02 ... 3.24822986e-03
#    2.92359246e-03 1.20317520e-04]
#   [3.13492604e-02 5.48203997e-02 1.60877611e-02 ... 5.25362138e-03
#    3.47516406e-03 3.90273854e-05]]
#
#  [[6.96757585e-02 1.06814325e-01 5.75379934e-03 ... 5.69113828e-02
#    3.87496538e-02 1.30449599e-02]
#   [5.96692301e-02 8.05636495e-02 0.00000000e+00 ... 4.66376767e-02
#    3.28401737e-02 1.11126797e-02]
#   [4.95372042e-02 5.55601344e-02 0.00000000e+00 ... 3.57194319e-02
#    2.68781818e-02 9.20977537e-03]
#   ...
#   [9.79063809e-02 1.86955974e-01 1.32784322e-01 ... 7.36181065e-02
#    5.41702434e-02 1.87501367e-02]
#   [8.88970867e-02 1.60691753e-01 8.98265168e-02 ... 7.12669566e-02
#    4.95807044e-02 1.68905556e-02]
#   [7.94530138e-02 1.33741915e-01 4.68678139e-02 ... 6.54534772e-02
#    4.43925224e-02 1.49799278e-02]]
#
#  ...
#
#  [[3.12170172e+00 3.13413715e+00 2.81232476e+00 ... 2.41745782e+00
#    2.37431788e+00 2.25692010e+00]
#   [3.10917115e+00 3.11286044e+00 2.78795791e+00 ... 2.39766192e+00
#    2.35886145e+00 2.24968481e+00]
#   [3.09621453e+00 3.09296036e+00 2.76953268e+00 ... 2.37530923e+00
#    2.34246349e+00 2.24226093e+00]
#   ...
#   [3.15586138e+00 3.20212412e+00 2.91098642e+00 ... 2.44916320e+00
#    2.41323662e+00 2.27699256e+00]
#   [3.14513493e+00 3.17925549e+00 2.87512279e+00 ... 2.44405651e+00
#    2.40157461e+00 2.27062011e+00]
#   [3.13371921e+00 3.15642023e+00 2.84176922e+00 ... 2.43329263e+00
#    2.38859916e+00 2.26391459e+00]]
#
#  [[3.13521290e+00 3.14732671e+00 2.83304453e+00 ... 2.44420695e+00
#    2.39838839e+00 2.28500366e+00]
#   [3.12286687e+00 3.12621117e+00 2.80871725e+00 ... 2.42405057e+00
#    2.38328195e+00 2.27794075e+00]
#   [3.11011076e+00 3.10655642e+00 2.79038763e+00 ... 2.40132642e+00
#    2.36731410e+00 2.27069831e+00]
#   ...
#   [3.16891837e+00 3.21523023e+00 2.93189240e+00 ... 2.47666025e+00
#    2.43667197e+00 2.30463982e+00]
#   [3.15832615e+00 3.19233680e+00 2.89591026e+00 ... 2.47137380e+00
#    2.42516136e+00 2.29839826e+00]
#   [3.14706206e+00 3.16952467e+00 2.86249709e+00 ... 2.46035910e+00
#    2.41239405e+00 2.29183841e+00]]
#
#  [[3.15169835e+00 3.16719699e+00 2.86108375e+00 ... 2.47079778e+00
#    2.42651415e+00 2.31287122e+00]
#   [3.13943624e+00 3.14587879e+00 2.83724952e+00 ... 2.45154738e+00
#    2.41174006e+00 2.30584288e+00]
#   [3.12677670e+00 3.12596726e+00 2.81925535e+00 ... 2.42961001e+00
#    2.39604521e+00 2.29863143e+00]
#   ...
#   [3.18519068e+00 3.23531532e+00 2.95789170e+00 ... 2.50018740e+00
#    2.46358991e+00 2.33237839e+00]
#   [3.17466450e+00 3.21241641e+00 2.92264104e+00 ... 2.49594212e+00
#    2.45249820e+00 2.32618332e+00]
#   [3.16347098e+00 3.18953276e+00 2.88992333e+00 ... 2.48595929e+00
#    2.44014072e+00 2.31966662e+00]]])]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 14
#      11 print(type(atm_pred))
#      13 # This function seems to have trouble dealing with stacked data.
# ---> 14 pred_ds = atm_model.model.predictions_to_xarray(pred["atm"])
#
# File ~/projects/jax-gcm/jcm/model.py:348, in Model.predictions_to_xarray(self, predictions)
#     344 physics_predictions = predictions.physics
#     346 # prepare physics predictions for xarray conversion
#     347 # (e.g. separate multi-channel fields so they are compatible with data_to_xarray)
# --> 348 physics_preds_dict = self.physics.data_struct_to_dict(physics_predictions, self.geometry)
#     350 times = jax.device_get(predictions.times)
#     352 pred_ds = data_to_xarray(dynamics_predictions.asdict() | physics_preds_dict, coords=self.coords, times=times - times[0])
#
# File ~/projects/jax-gcm/jcm/physics_interface.py:187, in Physics.data_struct_to_dict(self, struct, geometry, sep)
#     185 for k in _original_keys:
#     186     print(items[k])
# --> 187     s = items[k].shape
#     188     if len(s) == 5 and s[1:-1] == geometry.nodal_shape or len(s) == 4 and s[1:-1] == geometry.nodal_shape[1:]:
#     189         items.update({f"{k}{sep}{i}": items[k][..., i] for i in range(s[-1])})
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
pred_ds["u_wind"].isel(level=2, time=time_slice).plot.contourf(x='lon', y='lat', col="time", col_wrap=3, cmap="bwr", levels=np.linspace(-1, 1, 21)*30)

# %%
pred_ds["specific_humidity"].isel(level=0, time=time_slice).plot(x='lon', y='lat', col="time", col_wrap=3)

# %%
pred_ds["surface_flux.tskin"].isel(time=time_slice).plot(x='lon', y='lat', col="time", col_wrap=3)

# %% [markdown]
# ## Verify the atmosphere sees the same SST as ocean gives

# %%
print("The result should be zero, or very small numbers.")

daily_sst_atm = pred_ds["surface_flux.tskin"].isel(time=time_slice).isel(time=slice(1, None, None))
daily_sst_ocn = ocn_traj_ds["T"].isel(time=slice(0, -1, None))

SST_diff = daily_sst_atm - daily_sst_ocn 
SST_diff.plot.contourf(x='lon', y='lat', col="time", col_wrap=3, cmap="bwr")
